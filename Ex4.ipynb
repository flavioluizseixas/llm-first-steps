# %% [markdown]
# [![Abrir no Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flavioluizseixas/llm-first-steps/blob/main/Ex4.ipynb)

# %% [markdown]
# ## 🔴 4. Chatbot com RAG a partir de PDF (Perguntas Baseadas em Contexto)
#
# **🔹 Enunciado:**
# Implemente um sistema de RAG (Retrieval-Augmented Generation) com suporte a upload de PDF. O chatbot deve responder perguntas com base no conteúdo extraído do documento.
#
# **🧩 Implementação:**
# O notebook foi reorganizado para mostrar o pipeline completo:
# 1. carregar o modelo gerador;
# 2. carregar o modelo de embeddings;
# 3. extrair e dividir o PDF em chunks;
# 4. indexar os chunks com FAISS;
# 5. recuperar os trechos mais relevantes;
# 6. responder usando contexto recuperado.
#
# **🚀 Resultados Esperados:**
# - Upload e indexação de PDF textual.
# - Recuperação de contexto em português com embeddings multilíngues.
# - Respostas mais consistentes do que a versão com TinyLlama e top-1 chunk único.

# %%
# !pip install -q gradio PyMuPDF faiss-cpu sentence-transformers transformers accelerate

# %%
import faiss
import fitz  # PyMuPDF
import gradio as gr
import torch
from sentence_transformers import SentenceTransformer
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
GENERATION_MODEL_ID = "Qwen/Qwen2.5-3B-Instruct"
EMBEDDING_MODEL_ID = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
SYSTEM_PROMPT = (
    "Você é um assistente que responde em português usando apenas o contexto recuperado do PDF. "
    "Se o contexto não trouxer a resposta, diga isso com clareza."
)
GENERATION_CONFIG = {
    "max_new_tokens": 220,
    "temperature": 0.3,
    "top_p": 0.9,
    "do_sample": True,
}
CHUNK_SIZE = 800
CHUNK_OVERLAP = 120
TOP_K = 3


def carregar_modelo_geracao(model_id=GENERATION_MODEL_ID):
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    model = AutoModelForCausalLM.from_pretrained(
        model_id,
        torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
        device_map="auto",
    )
    return tokenizer, model


def dividir_em_chunks(texto, tamanho=CHUNK_SIZE, sobreposicao=CHUNK_OVERLAP):
    texto = " ".join(texto.split())
    if not texto:
        return []

    chunks = []
    inicio = 0
    passo = max(1, tamanho - sobreposicao)
    while inicio < len(texto):
        fim = inicio + tamanho
        chunks.append(texto[inicio:fim])
        inicio += passo
    return chunks


tokenizer, model = carregar_modelo_geracao()
embed_model = SentenceTransformer(EMBEDDING_MODEL_ID)

# %%
index = None
chunk_texts = []

# %%
def extrair_texto_pdf(caminho_pdf):
    doc = fitz.open(caminho_pdf)
    paginas = [pagina.get_text() for pagina in doc]
    return "\n".join(paginas)


def processar_pdf(pdf):
    global index, chunk_texts

    if pdf is None:
        return "Envie um PDF para começar."

    texto = extrair_texto_pdf(pdf.name)
    chunk_texts = dividir_em_chunks(texto)

    if not chunk_texts:
        index = None
        return "Não encontrei texto legível no PDF enviado."

    embeddings = embed_model.encode(chunk_texts, convert_to_numpy=True).astype("float32")
    faiss.normalize_L2(embeddings)

    index = faiss.IndexFlatIP(embeddings.shape[1])
    index.add(embeddings)

    return f"PDF processado com sucesso. {len(chunk_texts)} chunks foram indexados."

# %%
def recuperar_contexto(pergunta, k=TOP_K):
    embeddings_pergunta = embed_model.encode([pergunta], convert_to_numpy=True).astype("float32")
    faiss.normalize_L2(embeddings_pergunta)

    _, indices = index.search(embeddings_pergunta, k=k)
    trechos = [chunk_texts[i] for i in indices[0] if i < len(chunk_texts)]
    return "\n\n".join(f"Trecho {pos + 1}: {trecho}" for pos, trecho in enumerate(trechos))


def gerar_resposta_rag(pergunta, historico):
    contexto = recuperar_contexto(pergunta)

    mensagens = [{"role": "system", "content": SYSTEM_PROMPT}]
    for pergunta_anterior, resposta_anterior in historico[-3:]:
        mensagens.append({"role": "user", "content": pergunta_anterior})
        mensagens.append({"role": "assistant", "content": resposta_anterior})
    mensagens.append(
        {
            "role": "user",
            "content": f"Contexto recuperado:\n{contexto}\n\nPergunta: {pergunta}",
        }
    )

    prompt = tokenizer.apply_chat_template(
        mensagens,
        tokenize=False,
        add_generation_prompt=True,
    )
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    outputs = model.generate(**inputs, **GENERATION_CONFIG)
    novos_tokens = outputs[0][inputs["input_ids"].shape[1]:]
    return tokenizer.decode(novos_tokens, skip_special_tokens=True).strip()


def responder(pergunta, historico):
    if index is None:
        return "", historico, historico

    pergunta = pergunta.strip()
    if not pergunta:
        return "", historico, historico

    resposta = gerar_resposta_rag(pergunta, historico)
    novo_historico = historico + [(pergunta, resposta)]
    return "", novo_historico, novo_historico


def limpar_conversa():
    return [], []

# %%
with gr.Blocks() as demo:
    gr.Markdown("## 🧠 RAG com PDF em Português")
    gr.Markdown("Envie um PDF, aguarde a indexação e depois faça perguntas sobre o conteúdo.")

    upload = gr.File(label="Envie um PDF")
    status = gr.Markdown("Nenhum PDF processado ainda.")
    chatbot = gr.Chatbot(label="Conversa", height=420)
    entrada = gr.Textbox(label="Digite sua pergunta sobre o PDF")
    limpar = gr.Button("Limpar conversa")
    estado = gr.State([])

    upload.change(processar_pdf, inputs=upload, outputs=status)
    entrada.submit(responder, [entrada, estado], [entrada, chatbot, estado])
    limpar.click(limpar_conversa, outputs=[chatbot, estado])

demo.launch()
